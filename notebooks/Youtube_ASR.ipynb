# %% [markdown]
# # **Youtube Videos Transcription with OpenAI's Whisper**
#
# [![blog post shield](https://img.shields.io/static/v1?label=&message=Blog%20post&color=blue&style=for-the-badge&logo=openai&link=https://openai.com/blog/whisper)](https://openai.com/blog/whisper)
# [![notebook shield](https://img.shields.io/static/v1?label=&message=Notebook&color=blue&style=for-the-badge&logo=googlecolab&link=https://colab.research.google.com/github/openai/whisper/blob/main/notebooks/Youtube_ASR.ipynb)](https://colab.research.google.com/github/openai/whisper/blob/main/notebooks/Youtube_ASR.ipynb)
# [![repository shield](https://img.shields.io/static/v1?label=&message=Repository&color=blue&style=for-the-badge&logo=github&link=https://github.com/openai/whisper)](https://github.com/openai/whisper)
# [![paper shield](https://img.shields.io/static/v1?label=&message=Paper&color=blue&style=for-the-badge&link=https://cdn.openai.com/papers/whisper.pdf)](https://cdn.openai.com/papers/whisper.pdf)
# [![model card shield](https://img.shields.io/static/v1?label=&message=Model%20card&color=blue&style=for-the-badge&link=https://github.com/openai/whisper/blob/main/model-card.md)](https://github.com/openai/whisper/blob/main/model-card.md)
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription of a Youtube video using Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the transcript and video audio in your Google Drive.
#
# ---
#
# Notebook by [Arthur Findelair](https://github.com/ArthurFDLR).

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-3d1be9d3-06a1-1d43-76d8-3c2bc63fc5f2)
# Mon Oct 17 16:52:41 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Whisper.

#@markdown ---

! pip install git+https://github.com/openai/whisper.git
! pip install pytube

import sys
import warnings
import whisper
from pathlib import Path
import pytube
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-utonulm4
#   Running command git clone -q https://github.com/openai/whisper.git /tmp/pip-req-build-utonulm4
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from whisper==1.0) (1.21.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from whisper==1.0) (1.12.1+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from whisper==1.0) (4.64.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from whisper==1.0) (8.14.0)
# Collecting transformers>=4.19.0
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 8.3 MB/s
# Collecting ffmpeg-python==0.2.0
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from ffmpeg-python==0.2.0->whisper==1.0) (0.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.19.0->whisper==1.0) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.19.0->whisper==1.0) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=4.19.0->whisper==1.0) (5.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers>=4.19.0->whisper==1.0) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 53.1 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.19.0->whisper==1.0) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.19.0->whisper==1.0) (3.8.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 47.9 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers>=4.19.0->whisper==1.0) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers>=4.19.0->whisper==1.0) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=4.19.0->whisper==1.0) (3.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=4.19.0->whisper==1.0) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=4.19.0->whisper==1.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=4.19.0->whisper==1.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=4.19.0->whisper==1.0) (1.24.3)
# Building wheels for collected packages: whisper
#   Building wheel for whisper (setup.py) ... done
#   Created wheel for whisper: filename=whisper-1.0-py3-none-any.whl size=1175147 sha256=e16258defd5a0865f21d590fc2ccf37f7e0fc82b3835ce4bbc5bce9dd41abebb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uudtwf2r/wheels/16/15/89/1c7bb31bd0006793a95549d04785121a8a36daad9158e1e43a
# Successfully built whisper
# Installing collected packages: tokenizers, huggingface-hub, transformers, ffmpeg-python, whisper
# Successfully installed ffmpeg-python-0.2.0 huggingface-hub-0.10.1 tokenizers-0.13.1 transformers-4.23.1 whisper-1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytube
#   Downloading pytube-12.1.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.4 MB/s
# Installing collected packages: pytube
# Successfully installed pytube-12.1.0
# Using device: cuda:0

# %%
#@markdown # **Optional:** Save data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell if you want to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "Colab Notebooks/Whisper Youtube" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
#@markdown # **Model selection** 🧠

#@markdown As of the first public release, there are 4 pre-trained options to play with:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~1 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~2 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~5 GB     |      ~2x       |
#@markdown | large  |   1550 M   |        N/A         |      `large`       |    ~10 GB     |       1x       |

#@markdown ---
Model = 'large' #@param ['tiny.en', 'tiny', 'base.en', 'base', 'small.en', 'small', 'medium.en', 'medium', 'large']
#@markdown ---
#@markdown **Run this cell again if you change the model.**

whisper_model = whisper.load_model(Model)

if Model in whisper.available_models():
    display(Markdown(
        f"**{Model} model is selected.**"
    ))
else:
    display(Markdown(
        f"**{Model} model is no longer available.**<br /> Please select one of the following:<br /> - {'<br /> - '.join(whisper.available_models())}"
    ))
# Out:
# 100%|██████████████████████████████████████| 2.87G/2.87G [00:12<00:00, 239MiB/s]
# **large model is selected.**

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video you want to transcribe, wether you want to save the audio file in your Google Drive, and run the cell.

Type = "Google Drive" #@param ['Youtube', 'Google Drive']
#@markdown ---
#@markdown #### **Youtube video**
URL = "https://youtu.be/bIrEM2FbOLU" #@param {type:"string"}
store_audio = False #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video or audio (mp4, wav)**
video_path = "Colab Notebooks/Whisper Youtube/a_hassan09082022.mp3" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

if Type == "Youtube":
    video_yt = pytube.YouTube(URL)

    try:
        video_yt.check_availability()
        display(
            YouTubeVideo(video_yt.video_id)
        )
    except pytube.exceptions.VideoUnavailable:
        display(
            Markdown(f"**{URL} isn't available.**"),
        )
        raise(RuntimeError(f"{URL} isn't available."))
    video_path_local = Path(".").resolve() / (video_yt.video_id+".mp4")
    video_yt.streams.filter(
        type="audio",
        mime_type="audio/mp4",
        abr="48kbps"
    ).first().download(
        output_path = video_path_local.parent,
        filename = video_path_local.name
    )
    if store_audio:
        shutil.copy(video_path_local, drive_whisper_path / video_path_local.name)

elif Type == "Google Drive":
    video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path_local = Path(".").resolve() / (video_path_drive.name)
    shutil.copy(video_path_drive, video_path_local)
    if video_path_drive.is_file():
        display(Markdown(f"**{str(video_path_drive)} selected for transcription.**"))
    else:
        display(Markdown(f"**{str(video_path_drive)} does not exists.**"))
        raise(RuntimeError(f"{str(video_path_drive)} does not exists."))
else:
    raise(TypeError("Please select supported input type."))

if video_path_local.suffix == ".mp4":
    video_path_local = video_path_local.with_suffix(".wav")
    result  = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(".mp4")), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])
# Out:
# **/content/drive/My Drive/Colab Notebooks/Whisper Youtube/a_hassan09082022.mp3 selected for transcription.**

# %%
#@markdown # **Run the model** 🚀

#@markdown Run this cell to execute the transcription of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown ---
language = "Arabic" #@param ['Auto detection', 'Afrikaans', 'Albanian', 'Amharic', 'Arabic', 'Armenian', 'Assamese', 'Azerbaijani', 'Bashkir', 'Basque', 'Belarusian', 'Bengali', 'Bosnian', 'Breton', 'Bulgarian', 'Burmese', 'Castilian', 'Catalan', 'Chinese', 'Croatian', 'Czech', 'Danish', 'Dutch', 'English', 'Estonian', 'Faroese', 'Finnish', 'Flemish', 'French', 'Galician', 'Georgian', 'German', 'Greek', 'Gujarati', 'Haitian', 'Haitian Creole', 'Hausa', 'Hawaiian', 'Hebrew', 'Hindi', 'Hungarian', 'Icelandic', 'Indonesian', 'Italian', 'Japanese', 'Javanese', 'Kannada', 'Kazakh', 'Khmer', 'Korean', 'Lao', 'Latin', 'Latvian', 'Letzeburgesch', 'Lingala', 'Lithuanian', 'Luxembourgish', 'Macedonian', 'Malagasy', 'Malay', 'Malayalam', 'Maltese', 'Maori', 'Marathi', 'Moldavian', 'Moldovan', 'Mongolian', 'Myanmar', 'Nepali', 'Norwegian', 'Nynorsk', 'Occitan', 'Panjabi', 'Pashto', 'Persian', 'Polish', 'Portuguese', 'Punjabi', 'Pushto', 'Romanian', 'Russian', 'Sanskrit', 'Serbian', 'Shona', 'Sindhi', 'Sinhala', 'Sinhalese', 'Slovak', 'Slovenian', 'Somali', 'Spanish', 'Sundanese', 'Swahili', 'Swedish', 'Tagalog', 'Tajik', 'Tamil', 'Tatar', 'Telugu', 'Thai', 'Tibetan', 'Turkish', 'Turkmen', 'Ukrainian', 'Urdu', 'Uzbek', 'Valencian', 'Vietnamese', 'Welsh', 'Yiddish', 'Yoruba']
#@markdown > Language spoken in the audio, use `Auto detection` to let Whisper detect the language.
#@markdown ---
verbose = 'Live transcription' #@param ['Live transcription', 'Progress bar', 'None']
#@markdown > Whether to print out the progress and debug messages.
#@markdown ---
output_type = 'All' #@param ['All', '.txt', '.vtt', '.srt']
#@markdown > Type of file to generate to record the transcription.
#@markdown ---
task = 'transcribe' #@param ['transcribe', 'translate']
#@markdown > Whether to perform X->X speech recognition (`transcribe`) or X->English translation (`translate`).
#@markdown ---

#@markdown <br/>

#@markdown ### **Optional: Fine tunning** 
#@markdown ---
temperature = 0.15 #@param {type:"slider", min:0, max:1, step:0.05}
#@markdown > Temperature to use for sampling.
#@markdown ---
temperature_increment_on_fallback = 0.2 #@param {type:"slider", min:0, max:1, step:0.05}
#@markdown > Temperature to increase when falling back when the decoding fails to meet either of the thresholds below.
#@markdown ---
best_of = 5 #@param {type:"integer"}
#@markdown > Number of candidates when sampling with non-zero temperature.
#@markdown ---
beam_size = 5 #@param {type:"integer"}
#@markdown > Number of beams in beam search, only applicable when temperature is zero.
#@markdown ---
patience = 1.0 #@param {type:"number"}
#@markdown > Optional patience value to use in beam decoding, as in [*Beam Decoding with Controlled Patience*](https://arxiv.org/abs/2204.05424), the default (1.0) is equivalent to conventional beam search.
#@markdown ---
length_penalty = -0.05 #@param {type:"slider", min:-0.05, max:1, step:0.05}
#@markdown > Optional token length penalty coefficient (alpha) as in [*Google's Neural Machine Translation System*](https://arxiv.org/abs/1609.08144), set to negative value to uses simple length normalization.
#@markdown ---
suppress_tokens = "-1" #@param {type:"string"}
#@markdown > Comma-separated list of token ids to suppress during sampling; '-1' will suppress most special characters except common punctuations.
#@markdown ---
initial_prompt = "" #@param {type:"string"}
#@markdown > Optional text to provide as a prompt for the first window.
#@markdown ---
condition_on_previous_text = True #@param {type:"boolean"}
#@markdown > if True, provide the previous output of the model as a prompt for the next window; disabling may make the text inconsistent across windows, but the model becomes less prone to getting stuck in a failure loop.
#@markdown ---
fp16 = True #@param {type:"boolean"}
#@markdown > whether to perform inference in fp16.
#@markdown ---
compression_ratio_threshold = 2.4 #@param {type:"number"}
#@markdown > If the gzip compression ratio is higher than this value, treat the decoding as failed.
#@markdown ---
logprob_threshold = -1.0 #@param {type:"number"}
#@markdown > If the average log probability is lower than this value, treat the decoding as failed.
#@markdown ---
no_speech_threshold = 0.6 #@param {type:"slider", min:-0.0, max:1, step:0.05}
#@markdown > If the probability of the <|nospeech|> token is higher than this value AND the decoding has failed due to `logprob_threshold`, consider the segment as silence.
#@markdown ---

verbose_lut = {
    'Live transcription': True,
    'Progress bar': False,
    'None': None
}

args = dict(
    language = (None if language == "Auto detection" else language),
    verbose = verbose_lut[verbose],
    task = task,
    temperature = temperature,
    temperature_increment_on_fallback = temperature_increment_on_fallback,
    best_of = best_of,
    beam_size = beam_size,
    patience=patience,
    length_penalty=(length_penalty if length_penalty>=0.0 else None),
    suppress_tokens=suppress_tokens,
    initial_prompt=(None if not initial_prompt else initial_prompt),
    condition_on_previous_text=condition_on_previous_text,
    fp16=fp16,
    compression_ratio_threshold=compression_ratio_threshold,
    logprob_threshold=logprob_threshold,
    no_speech_threshold=no_speech_threshold
)

temperature = args.pop("temperature")
temperature_increment_on_fallback = args.pop("temperature_increment_on_fallback")
if temperature_increment_on_fallback is not None:
    temperature = tuple(np.arange(temperature, 1.0 + 1e-6, temperature_increment_on_fallback))
else:
    temperature = [temperature]

if Model.endswith(".en") and args["language"] not in {"en", "English"}:
    warnings.warn(f"{Model} is an English-only model but receipted '{args['language']}'; using English instead.")
    args["language"] = "en"

video_transcription = whisper.transcribe(
    whisper_model,
    str(video_path_local),
    temperature=temperature,
    **args,
)

# Save output
writing_lut = {
    '.txt': whisper.utils.write_txt,
    '.vtt': whisper.utils.write_vtt,
    '.srt': whisper.utils.write_txt,
}

if output_type == "All":
    for suffix, write_suffix in writing_lut.items():
        transcript_local_path = video_path_local.with_suffix(suffix)
        with open(transcript_local_path, "w", encoding="utf-8") as f:
            write_suffix(video_transcription["segments"], file=f)
        try:
            transcript_drive_path = drive_whisper_path / transcript_local_path.name
            shutil.copy(transcript_local_path, transcript_drive_path)
            display(Markdown(f"**Transcript file created: {transcript_drive_path}**"))
        except:
            display(Markdown(f"**Transcript file created: {transcript_local_path}**"))
else:
    transcript_local_path = video_path_local.with_suffix(output_type)

    with open(transcript_local_path, "w", encoding="utf-8") as f:
        writing_lut[output_type](video_transcription["segments"], file=f)
    try:
        transcript_drive_path = drive_whisper_path / transcript_local_path.name
        shutil.copy(transcript_local_path, transcript_drive_path)
        display(Markdown(f"**Transcript file created: {transcript_drive_path}**"))
    except:
        display(Markdown(f"**Transcript file created: {transcript_local_path}**"))
# Out:
# [00:00.000 --> 00:02.000]  اعوذ بالله من الشيطان الرجيم
# [00:02.000 --> 00:04.000]  بسم الله الرحمن الرحيم
# [00:06.000 --> 00:08.000]  الحمد لله رب العالمين
# [00:14.000 --> 00:16.000]  مشكورين مأجورين ان شاء الله
# [00:16.000 --> 00:18.000]  منون
# [00:18.000 --> 00:20.000]  الحمد لله رب العالمين
# [00:20.000 --> 00:24.000]  والصلاة والسلام على سيدنا ونبينا
# [00:24.000 --> 00:26.000]  خاتم النبينا
# [00:26.000 --> 00:28.000]  ابو القاسم محمد ابن عبد الله
# [00:28.000 --> 00:32.000]  وعلى اله الطيبين الطاهرين
# [00:32.000 --> 00:36.000]  واصحابه الاخيار المنتجبين
# [00:36.000 --> 00:38.000]  وعلى جميع الانبياء والمرسلين
# [00:38.000 --> 00:42.000]  من زيارة يوم العاشر
# [00:42.000 --> 00:46.000]  السلام على الحسين بن علي الشهيد
# [00:46.000 --> 00:50.000]  السلام على علي بن الحسين الشهيد
# [00:50.000 --> 00:54.000]  السلام على العباس بن امير المؤمنين الشهيد
# [00:54.000 --> 00:58.000]  السلام على الشهداء بن ولد امير المؤمنين
# [00:58.000 --> 01:02.000]  السلام على الشهداء بن ولد الحسن
# [01:02.000 --> 01:06.000]  السلام على الشهداء بن ولد الحسين
# [01:06.000 --> 01:10.000]  السلام على الشهداء بن ولد جعفر وعقيل
# [01:10.000 --> 01:14.000]  السلام على كل مستشهد معهم من المؤمنين
# [01:14.000 --> 01:18.000]  اللهم صل على محمد وآل محمد
# [01:18.000 --> 01:22.000]  وبلغهم عني تحيينا
# [01:22.000 --> 01:26.000]  وبلغهم عني تحيينا
# [01:26.000 --> 01:30.000]  السلام عليك يا رسول الله
# [01:30.000 --> 01:34.000]  احسن الله لك العزاء في ولدك الحسين
# [01:34.000 --> 01:38.000]  السلام عليك يا فاطمة
# [01:38.000 --> 01:42.000]  احسن الله لك العزاء في ولدك الحسين
# [01:42.000 --> 01:46.000]  السلام عليك يا امير المؤمنين
# [01:46.000 --> 01:50.000]  احسن الله لك العزاء في ولدك الحسين
# [01:50.000 --> 01:54.000]  السلام عليك يا ابا محمد الحسن
# [01:54.000 --> 01:58.000]  احسن الله لك العزاء في أخيك الحسين
# [01:58.000 --> 02:02.000]  السلام عليكم يا ائمتي وسادتي
# [02:02.000 --> 02:06.000]  السلام عليك يا صاحب الزمان
# [02:06.000 --> 02:10.000]  عظم الله لكم الأجوى
# [02:10.000 --> 02:14.000]  وأحسن لكم العزاء
# [02:14.000 --> 02:18.000]  بشهادة الحسين بأبيكم الحسين
# [02:18.000 --> 02:22.000]  سلام عليكم جميعا
# [02:22.000 --> 02:26.000]  ورحمة الله وبركاته
# [02:26.000 --> 02:30.000]  انا وانتم في هذه الساعة نتوجه
# [02:30.000 --> 02:34.000]  بالعزاء الى صاحب العزاء
# [02:34.000 --> 02:38.000]  الى حفيد الحسين عليه السلام
# [02:38.000 --> 02:42.000]  الى بقية الله في العراضين
# [02:42.000 --> 02:46.000]  الامام الحجة بن الحسن العسكري المهدي
# [02:46.000 --> 02:50.000]  ونقدم له الفداء
# [02:50.000 --> 02:54.000]  نقدم له عزاءنا ومواساتنا
# [02:54.000 --> 02:58.000]  ونعبر له عن آلامنا
# [02:58.000 --> 03:02.000]  وأحزاننا ومشاركتنا له
# [03:02.000 --> 03:06.000]  في هذا المصاب الجلل والأليم
# [03:06.000 --> 03:10.000]  والذي يبكي فيه جده بدل الدموع دم
# [03:10.000 --> 03:14.000]  أيضا نتوجه بالعزاء
# [03:14.000 --> 03:18.000]  بشهادة الحسين ورحمة الله وبركاته
# [03:18.000 --> 03:22.000]  ورحمة الله وبركاته
# [03:22.000 --> 03:26.000]  ورحمة الله وبركاته
# [03:26.000 --> 03:30.000]  ورحمة الله وبركاته
# [03:30.000 --> 03:34.000]  ورحمة الله وبركاته
# [03:34.000 --> 03:38.000]  ورحمة الله وبركاته
# [03:38.000 --> 03:42.000]  ورحمة الله وبركاته
# [03:42.000 --> 03:46.000]  ومشيت طوال هذه المسافة والآن
# [03:46.000 --> 03:50.000]  لساعات في حر الشمس لذلك
# [03:50.000 --> 03:54.000]  ستكون كلمتي مختصرة وفيها إشارة
# [03:54.000 --> 03:58.000]  إلى بعض المواقف وخصوصا
# [03:58.000 --> 04:02.000]  ما يعني في لبنان في آخر الكلمة
# [04:02.000 --> 04:06.000]  أولا أتوجه اليكم جميعا بالشكر
# [04:06.000 --> 04:10.000]  على هذا الحضور الكبير والمهيب والمواسي
# [04:10.000 --> 04:14.000]  لرسول الله ولآل رسول الله
# [04:14.000 --> 04:18.000]  ولصاحب الزمان عليه السلام
# [04:18.000 --> 04:22.000]  وأنتم تعبرون اليوم كما كنتم تعبرون
# [04:22.000 --> 04:26.000]  على مدى 40 ربيعا و40 عاما
# [04:26.000 --> 04:30.000]  عن وفائكم عن إخلاصكم
# [04:30.000 --> 04:34.000]  عن صدقكم عن ثباتكم
# [04:34.000 --> 04:38.000]  لم يمنعكم عن التعبير عن هذا الحب
# [04:38.000 --> 04:42.000]  وهذا العشق وهذا الولاء لا حرب
# [04:42.000 --> 04:46.000]  ولا قتال ولا سيارات مفخخة
# [04:46.000 --> 04:50.000]  ولا حرب ولا مطر ولا ثلج
# [04:50.000 --> 04:54.000]  على مدى 40 سنة الماضية
# [04:54.000 --> 04:58.000]  اليوم أيضا نحتشد في هذه الساحة
# [04:58.000 --> 05:02.000]  لنجدد بيعتنا وعهدنا
# [05:02.000 --> 05:06.000]  وميثاقنا مع رسول الله
# [05:06.000 --> 05:10.000]  مع سيد الشهداء أبي عبد الله الحسين
# [05:10.000 --> 05:14.000]  عليه السلام ونقول له كما قلنا
# [05:14.000 --> 05:18.000]  ليلة الأمس يا سيدنا وإمامنا
# [05:18.000 --> 05:22.000]  نحن باقون معك وفي طريقك
# [05:22.000 --> 05:26.000]  ننبي نداعك نحمل رايتك نحفظ
# [05:26.000 --> 05:30.000]  إسلام جدك الذي استشهدته من أجل
# [05:30.000 --> 05:34.000]  بقائه وحفظه ندافع عن عزة أمتنا
# [05:34.000 --> 05:38.000]  التي استشهدته من أجل أن تبقى
# [05:38.000 --> 05:42.000]  عزيزة فلا يذلها
# [05:42.000 --> 05:46.000]  لا يزيد ولا بن زياد في عالم
# [05:46.000 --> 05:50.000]  مليء بالطواغيت نحن اليوم
# [05:50.000 --> 05:54.000]  ومن موقع الجهاد وفي ميادين الجهاد
# [05:54.000 --> 05:58.000]  نجدد لك يا أبا عبد الله رجالا
# [05:58.000 --> 06:02.000]  ونساء وشيبا وشبانا
# [06:02.000 --> 06:06.000]  وصغارا وكبارا نجدد لك
# [06:06.000 --> 06:10.000]  عهدنا وباعتنا وصدقنا
# [06:10.000 --> 06:14.000]  وإخلاصنا والتزامنا في هذا الطريق
# [06:14.000 --> 06:18.000]  الذي لن نتخلى عنه مهما
# [06:18.000 --> 06:22.000]  كانت تضحيات فكما كنا نقول
# [06:22.000 --> 06:26.000]  على مدى العربعين عاما في جبهات القتال
# [06:26.000 --> 06:30.000]  في محاور المقاومة في تشييع الشهداء
# [06:30.000 --> 06:34.000]  في الموقف السياسي في مواجهات التحدي
# [06:34.000 --> 06:38.000]  في كل الميادين لبيك يا حسين
# [06:38.000 --> 06:58.000]  لبيك يا حسين
# [06:58.000 --> 07:02.000]  يوم نصرة المظلوم يوم عاشراء
# [07:02.000 --> 07:06.000]  هو يوم نصرة المظلوم
# [07:06.000 --> 07:10.000]  أبدأ بكلمة للتعبير عن المواسات
# [07:10.000 --> 07:14.000]  للمظلومين في نجيريا
# [07:14.000 --> 07:18.000]  عادة نبدأ من فلسطين ولكن اسمحوا لي
# [07:18.000 --> 07:22.000]  أن أبدأ من نجيريا هناك
# [07:22.000 --> 07:26.000]  أتباع لأهل البيت عليه السلام
# [07:26.000 --> 07:30.000]  وما زالوا حتى الآن في كل سنة
# [07:30.000 --> 07:34.000]  عندما احيون يوم العاشر ويخرجون في مواكبهم
# [07:34.000 --> 07:38.000]  السلمية الحسينية رجالا ونساء
# [07:38.000 --> 07:42.000]  يطلق عليهم النار ويصفط منهم الشهداء
# [07:42.000 --> 07:46.000]  من رجال والنساء والصغار
# [07:46.000 --> 07:50.000]  هذه المظلومية مازالت أيضا في هذا الزمن
# [07:50.000 --> 07:54.000]  تذكرنا بكل الأزمنة الماضية
# [07:54.000 --> 07:58.000]  ويقتل فيها زوار الحسين ويقتل فيها الباكونة
# [07:58.000 --> 08:02.000]  على الحسين ويقتل فيها من يحيي
# [08:02.000 --> 08:06.000]  ذكر الحسين عليه السلام
# [08:06.000 --> 08:10.000]  للأسف ما زال هذا الزمن قائما
# [08:10.000 --> 08:14.000]  في نجيريا موجود في أفغانستان موجود
# [08:14.000 --> 08:18.000]  في أماكن أخرى من العالم موجود وإن كانت
# [08:18.000 --> 08:22.000]  ابتعدت وأمنت فيه ساحات كثيرة
# [08:22.000 --> 08:26.000]  نحن في بداية الكلمة نعبر عن مواساتنا
# [08:26.000 --> 08:30.000]  للقائد الكبير في نجيريا المظلوم
# [08:30.000 --> 08:34.000]  المجاهد الصابر والد الشهداء
# [08:34.000 --> 08:38.000]  الشيخ الزكزكي ولعائلته ولكل عوائل
# [08:38.000 --> 08:42.000]  الشهداء نسأل الله أن يتقبلهم
# [08:42.000 --> 08:46.000]  في طريق الحسين ومع الحسين وأن يعجل شفاء
# [08:46.000 --> 08:50.000]  جرحاهم المسألة المركزية في يوم
# [08:50.000 --> 08:54.000]  هي فلسطين الأرض المحتلة
# [08:54.000 --> 08:58.000]  والمقدسات المغتصبة والشعب
# [08:58.000 --> 09:02.000]  المظلوم والمعذب والمضطهد
# [09:02.000 --> 09:06.000]  اليوم أيها الإخوة والأخوات يجب أن يكون
# [09:06.000 --> 09:10.000]  واضحا لكل ذي عقل وضمير
# [09:10.000 --> 09:14.000]  أن معيار الإنسانية وأن معيار
# [09:14.000 --> 09:18.000]  الإسلام وأن معيار الشرف
# [09:18.000 --> 09:22.000]  ولمن يبدع العروبة أن معيار العروبة
# [09:22.000 --> 09:26.000]  هو الموقف من فلسطين وما يجري فيها
# [09:26.000 --> 09:30.000]  وما يجري عليها شعبها المظلوم
# [09:30.000 --> 09:34.000]  هناك ثابت وأبي
# [09:34.000 --> 09:38.000]  وصامد صباح اليوم يقاتل في
# [09:38.000 --> 09:42.000]  نابلس وبالأمس وعلى مدى أيام
# [09:42.000 --> 09:46.000]  يقاتل في غزة لا يلين ولا يضعف
# [09:46.000 --> 09:50.000]  ولا يستكين ولا يخضع
# [09:50.000 --> 09:54.000]  وبالرغم من الحصار والخذلان والتخلي
# [09:54.000 --> 09:58.000]  وسكوت العالم يفرض قواعده
# [09:58.000 --> 10:02.000]  ومعادلاته وشروطه على العدو
# [10:02.000 --> 10:06.000]  ويزداد إيمانا يوما بعد يوم
# [10:06.000 --> 10:10.000]  بالمقاومة كخيار وحيد لتحرير الأرض
# [10:10.000 --> 10:14.000]  والمقدسات وحماية الوجود والكرامة
# [10:14.000 --> 10:18.000]  ويوما بعد يوم سيصل كل الشعب الفلسطيني
# [10:18.000 --> 10:22.000]  إذا بعد فيه شريحة معينة فئة معينة
# [10:22.000 --> 10:26.000]  ما زالت متردد أو حائرة أو ملتبس
# [10:26.000 --> 10:30.000]  عليها الخيارات سيأت اليوم قريبا
# [10:30.000 --> 10:34.000]  الذي سيصل فيه كل الشعب الفلسطيني
# [10:34.000 --> 10:38.000]  ليعلم وليؤمن وليحسم خياره
# [10:38.000 --> 10:42.000]  بأن المقاومة هي الطريق الوحيد لتحرير
# [10:42.000 --> 10:46.000]  المقدسات والاستعادة فلسطين
# [10:46.000 --> 10:50.000]  ولعودة الفلسطينيين المهجرين
# [10:50.000 --> 10:54.000]  في كل دول الشتاة والعالم
# [10:54.000 --> 10:58.000]  نحن لا نتوقع من المستكبرين
# [10:58.000 --> 11:02.000]  كالأمريكيين وامثالهم رحمة أو عدلا
# [11:02.000 --> 11:06.000]  ولكن نتوجه إلى
# [11:06.000 --> 11:10.000]  من يدعونا الانتساب إلى الإسلام
# [11:10.000 --> 11:14.000]  إلى العروبة ونسألهم أين هم
# [11:14.000 --> 11:18.000]  من دماء الأطفال والنساء المسفوكة
# [11:18.000 --> 11:22.000]  ظلما في غزة وفي الضفة
# [11:22.000 --> 11:26.000]  هذا العام وفي العام الماضي في سيف القدس
# [11:26.000 --> 11:30.000]  دماء هؤلاء الشهداء يجب أن نراه دائما
# [11:30.000 --> 11:34.000]  من موقع الإدانة على وجوه المطبعين
# [11:34.000 --> 11:38.000]  وعلى أيدي المستسلمين تصرخ فيهم
# [11:38.000 --> 11:42.000]  وتدعوهم إلى العودة والتوبة
# [11:42.000 --> 11:46.000]  في عاشر راء الحسين عليه السلام نعتز
# [11:46.000 --> 11:50.000]  بالمجاهدين والمقاومين في فلسطين
# [11:50.000 --> 11:54.000]  الذين قاتلوا ودائما كانوا يقاتلون
# [11:54.000 --> 11:58.000]  بثبات وشجاعة وصمود إسطوري
# [11:58.000 --> 12:02.000]  نعتز بقادتهم الشهداء الذين
# [12:02.000 --> 12:06.000]  سقطوا في الأيام الماضية نجدد التزامنا
# [12:06.000 --> 12:10.000]  في مسيرتنا اليوم كما كنا نفعل
# [12:10.000 --> 12:14.000]  في 40 عاما نجدد التزامنا
# [12:14.000 --> 12:18.000]  بهذه القضية المقدسة القضية الفلسطينية
# [12:18.000 --> 12:22.000]  ونجدد وقوفنا إلى جانب
# [12:22.000 --> 12:26.000]  هذا الشعب المجاهد والمقاوم
# [12:26.000 --> 12:30.000]  ونحن الموجودون دائما في الجبهة الأمامية
# [12:30.000 --> 12:34.000]  في الصراع مع هذا العدو الصهيوني الغاشم
# [12:34.000 --> 12:38.000]  من أبشع المطبعين أيها الأخوة والأخوات
# [12:38.000 --> 12:42.000]  نظام البحرين الذي أظهر
# [12:42.000 --> 12:46.000]  في الأيام القليلة الماضية إلى جانب
# [12:46.000 --> 12:50.000]  تسلطه وظلمه وتغيانه
# [12:50.000 --> 12:54.000]  أنه لا يطيق راية سوداء
# [12:54.000 --> 12:58.000]  ترمز إلى الحسين عليه السلام
# [12:58.000 --> 13:02.000]  ترفع في شارع في المنامة أو في قرية من قرى
# [13:02.000 --> 13:06.000]  البحرين أو على عمود أو على مدخل
# [13:06.000 --> 13:10.000]  منزل ولكنه يطيق
# [13:10.000 --> 13:14.000]  الصهاينة الذين يجولون في عاصمته
# [13:14.000 --> 13:18.000]  ويرقصون في نواديها
# [13:18.000 --> 13:22.000]  اليوم نستحضر مظلومية شعب البحرين
# [13:22.000 --> 13:26.000]  الأبي والصامر والمظلوم أمام تغمة
# [13:26.000 --> 13:30.000]  حاكمة فاسدة خائنة
# [13:30.000 --> 13:34.000]  تسلبه أبسط حقوقه الطبيعية
# [13:34.000 --> 13:38.000]  تعتدي على رموزه ومقدساته وتحتضن أعداءه
# [13:38.000 --> 13:42.000]  وتفرض التطبيع وهو الذي يرفض
# [13:42.000 --> 13:46.000]  التطبيع ويعلن عدائه المطلق
# [13:46.000 --> 13:50.000]  لإسرائيل ونصرته المطلقة لشعبها الفلسطيني
# [13:50.000 --> 13:54.000]  ومقاومته الأبية
# [13:54.000 --> 13:58.000]  في هذا اليوم أيضا في يوم المظلوم
# [13:58.000 --> 14:02.000]  يأتنا إلى جانب الشعب المجاهد
# [14:02.000 --> 14:06.000]  والمقاوم والمحاصر في اليمن
# [14:06.000 --> 14:10.000]  الذين يقاتلون منذ سنوات
# [14:10.000 --> 14:14.000]  دفاعا عن كرامتهم ووجودهم
# [14:14.000 --> 14:18.000]  ووطنهم في مواجهة الاحتلال
# [14:18.000 --> 14:22.000]  وفي مواجهة العدوان وفي مواجهة الإذلال
# [14:22.000 --> 14:26.000]  وفي مواجهة الاستكبار لا يعرفون
# [14:26.000 --> 14:30.000]  ملل ولا الملل يملؤون الجبهات
# [14:30.000 --> 14:34.000]  في الحرب وعلى امتداد السنوات
# [14:34.000 --> 14:38.000]  ويملؤون الساحات والميادين
# [14:38.000 --> 14:42.000]  ولا يغيبون عن مناسبات الأمة لا في يوم القدس
# [14:42.000 --> 14:46.000]  ولا في عشر وراء ولا في مولد النبي
# [14:46.000 --> 14:50.000]  ولا في نصرة فلسطين يتظاهرون لها
# [14:50.000 --> 14:54.000]  في الوقت الذي تغيب فيه أغلب
# [14:54.000 --> 14:58.000]  العالم العربي والإسلامي
# [14:58.000 --> 15:02.000]  وبرغم من كل آلامهم وجراحهم
# [15:02.000 --> 15:06.000]  ومظلوميتهم وغربتهم
# [15:06.000 --> 15:10.000]  هؤلاء الأبطال هذا الشعب الأبي المجاهد في اليمن
# [15:10.000 --> 15:14.000]  هو تيسيد حقيقي
# [15:14.000 --> 15:18.000]  في القتال والصمود وإباء الضيم
# [15:18.000 --> 15:22.000]  والشهادة والصبر وانتصار الدم على السيف
# [15:22.000 --> 15:26.000]  والثبات تيسيد حقيقي لكربلاء
# [15:26.000 --> 15:30.000]  ولسيد الشهداء أبي عبد الله الحسين عليه السلام
# [15:30.000 --> 15:34.000]  نجدد في عاشر رائنا
# [15:34.000 --> 15:38.000]  وقفتنا معهم دائما
# [15:38.000 --> 15:42.000]  ولا نخاف في ذلك لومة لائم
# [15:42.000 --> 15:46.000]  لا في لبنان ولا في المنطقة ولا في العالم
# [15:46.000 --> 15:50.000]  ونؤمن أن نصرتهم باللسان وبالمال وباليد
# [15:50.000 --> 15:54.000]  والوقوف إلى جانبهم من أوجب الواجبات
# [15:54.000 --> 15:58.000]  على جميع المسلمين والمصدعفين
# [15:58.000 --> 16:02.000]  والمظلومين والأحرار والشرفاء في هذا
# [16:02.000 --> 16:06.000]  العالم لأن ما يجري في اليمن منذ سنوات
# [16:06.000 --> 16:10.000]  هو عنوان كبير وعظيم
# [16:10.000 --> 16:14.000]  للمظلومية وللاضطهاد
# [16:14.000 --> 16:18.000]  وللعدوان الذي يمارس بأبشع ما يكون
# [16:18.000 --> 16:22.000]  العدوان وندعو إلى وقف الحرب
# [16:22.000 --> 16:26.000]  عليهم ورفع الحصار عنهم
# [16:26.000 --> 16:30.000]  وإنهاء هذا العدوان الغاشل
# [16:30.000 --> 16:34.000]  في العراق الأرض المباركة
# [16:34.000 --> 16:38.000]  والمقدسة والتي تحتضن سيدنا
# [16:38.000 --> 16:42.000]  سيد الشهداء وأصحابه وأهل
# [16:42.000 --> 16:46.000]  بيته من نحيي ذكراهم هذا اليوم
# [16:46.000 --> 16:50.000]  نرجو أن يتمكن كل الأعزاء هناك
# [16:50.000 --> 16:54.000]  من العمل بحكمة ومسؤولية
# [16:54.000 --> 16:58.000]  وصدق لتجاوز هذه المرحلة
# [16:58.000 --> 17:02.000]  الصعبة لينقذ العراق من أجل
# [17:02.000 --> 17:06.000]  شعب العراق ولينقذ العراق من أجل
# [17:06.000 --> 17:10.000]  الأمة كلها التي تشتاق
# [17:10.000 --> 17:14.000]  إلى موقع العراق ووقفته التاريخية
# [17:14.000 --> 17:18.000]  في صميم الأمة وفي جبهة الأمة
# [17:18.000 --> 17:22.000]  وفي صراع الأمة في قضاياها الكبرى
# [17:22.000 --> 17:26.000]  وفي مواجهة المستكبرين
# [17:26.000 --> 17:30.000]  في سوريا التي تخطت الحرب الكونية
# [17:30.000 --> 17:34.000]  عليها لكنها ما زالت تعاني من الحصار
# [17:34.000 --> 17:38.000]  يجب أن يرتفع الصوت أيضا في الأمة
# [17:38.000 --> 17:42.000]  في العالم العربي في العالم الإسلامي
# [17:42.000 --> 17:46.000]  لرفع العقوبات لإسقاط قانون قيصر
# [17:46.000 --> 17:50.000]  هناك اليوم مناطق ودول محاصرة
# [17:50.000 --> 17:54.000]  والعالم الإسلامي والعربي يقف ساكتا
# [17:54.000 --> 17:58.000]  غزة المحاصرة منذ أكثر من 15 عاما
# [17:58.000 --> 18:02.000]  اليمن المحاصرة منذ أكثر من 7 سنوات
# [18:02.000 --> 18:06.000]  سوريا المحاصرة
# [18:06.000 --> 18:10.000]  هذه شعوب ودول وحكومات
# [18:10.000 --> 18:14.000]  ومظلومون محاسرون ويراد
# [18:14.000 --> 18:18.000]  إخضاعهم بالحصار والعقوبات بعد أن
# [18:18.000 --> 18:22.000]  عجزوا عن إخضاعهم بالحروب الكونية
# [18:22.000 --> 18:26.000]  وبالعدوان وبالقتال وبقتل
# [18:26.000 --> 18:30.000]  الأطفال والصغار والكبار
# [18:30.000 --> 18:34.000]  إيران الإسلام بقيادة الإمام الخامنة
# [18:34.000 --> 18:38.000]  إذا مظله ستبقى في عيوننا قوة
# [18:38.000 --> 18:42.000]  الإسلام الكبرى وقلب محور المقاومة
# [18:42.000 --> 18:46.000]  وطليعة معسكر الحسين عليه السلام
# [18:46.000 --> 18:50.000]  في هذا الزمان وإلى قيام الساعة
# [18:50.000 --> 18:54.000]  وهي التي تحمل رايته
# [18:54.000 --> 18:58.000]  وتدافع عن كل مظلومي هذا العالم
# [18:58.000 --> 19:02.000]  نذكر في عاشراء الحسين سيد شهداء
# [19:02.000 --> 19:06.000]  محور المقاومة الشهيد القائد
# [19:06.000 --> 19:10.000]  الحاج قاسم سليماني ونذكر أخاه
# [19:10.000 --> 19:14.000]  القائد الجهادي الكبير أبا مهدي المهندس
# [19:14.000 --> 19:18.000]  في لبنان نحن شعب
# [19:18.000 --> 19:22.000]  مصر على الصمود
# [19:22.000 --> 19:26.000]  مصر على السيادة الحقيقية
# [19:26.000 --> 19:30.000]  وليس السيادة الوهمية وليس السيادة المزيفة
# [19:30.000 --> 19:34.000]  نحن شعب وتيار
# [19:34.000 --> 19:38.000]  مصر على أن نكون سادة قرارنا
# [19:38.000 --> 19:42.000]  كما نحن فعلا ولسنا أسلاما
# [19:42.000 --> 19:46.000]  في هذه السفارة أو تلك السفارة
# [19:46.000 --> 19:50.000]  نحن شعب واجهنا
# [19:50.000 --> 19:54.000]  على مدى 40 عاما الحروب
# [19:54.000 --> 19:58.000]  والمؤامرات والإغتيالات والسيارات المفخخة
# [19:58.000 --> 20:02.000]  والفتن ونواجه منذ سنوات
# [20:02.000 --> 20:06.000]  الحصار والعقوبات لكن هذا لن يفوت من
# [20:06.000 --> 20:10.000]  عزيمتنا شيئا سوف نبقى نتطلع
# [20:10.000 --> 20:14.000]  إلى مستقبل واعد للبنان ولشعب لبنان
# [20:14.000 --> 20:18.000]  لكل شعب لبنان بمسلميه ومسيحيه
# [20:18.000 --> 20:22.000]  نحن نتطلع إلى لبنان
# [20:22.000 --> 20:26.000]  القوي السيد الحر العزيز
# [20:26.000 --> 20:30.000]  القادر على حماية سيادته
# [20:30.000 --> 20:34.000]  وكرامته الآمن والقادر على استخراج
# [20:34.000 --> 20:38.000]  ثرواته الطبيعية أن يبقى نفطه
# [20:38.000 --> 20:42.000]  له وغازه له وماؤه له
# [20:42.000 --> 20:46.000]  وأن لا يسمح لأحد أن يسلب منه خيراته
# [20:46.000 --> 20:50.000]  وثرواته وأن اليد التي ستمتد
# [20:50.000 --> 20:54.000]  إلى أي ثروة من هذه الثروات ستقطع
# [20:54.000 --> 20:58.000]  تماما كاليد التي امتدت إلى عردنا
# [20:58.000 --> 21:02.000]  إلى دمائنا إلى شعوب إلى شعبنا
# [21:02.000 --> 21:06.000]  وإلى قرانا ومدننا نحن في لبنان
# [21:06.000 --> 21:10.000]  في هذا الموقع الذي نشعر فيه بالمسؤولية
# [21:10.000 --> 21:14.000]  تجاه شعبنا ندعو بكلمات مختصرة
# [21:14.000 --> 21:18.000]  إلى أقصى تعاون سياسي وشعبي
# [21:18.000 --> 21:22.000]  ورسمي لتجاوز الصعوبات
# [21:22.000 --> 21:26.000]  والأزمات الحالية وقادرون على ذلك
# [21:26.000 --> 21:30.000]  بإذن الله ندعو جديا
# [21:30.000 --> 21:34.000]  لتشكيل حكومة حقيقية كاملة الصلاحيات
# [21:34.000 --> 21:38.000]  وخصوصا أن هناك
# [21:38.000 --> 21:42.000]  من يبشرنا بفراغ رئاسي
# [21:42.000 --> 21:46.000]  ومن يتهدد لبنان بفراغ رئاسي
# [21:46.000 --> 21:50.000]  لا بد من حكومة حقيقية تتحمل مسؤوليات
# [21:50.000 --> 21:54.000]  فإذا أنجز الاستحقاق رئاسي فبها ونعمت
# [21:54.000 --> 21:58.000]  وإن لم ينجز في الحد الأدنى
# [21:58.000 --> 22:02.000]  ستكون هناك في لبنان حكومة قادرة على مواجهة الأزمات
# [22:02.000 --> 22:06.000]  على المسؤولين حقيقة
# [22:06.000 --> 22:10.000]  أن يشعروا بآلام الناس بأوجاع الناس
# [22:10.000 --> 22:14.000]  وأنا أقول لكم بصدق وصراحة
# [22:14.000 --> 22:18.000]  الإنسان يشعر بأن أغلب المسؤولين في هذا البلد
# [22:18.000 --> 22:22.000]  بعيدون كل البعد عن آلام الناس عن أحزان الناس
# [22:22.000 --> 22:26.000]  عن معاناة الناس يعيشون في بروجهم العاجية
# [22:26.000 --> 22:30.000]  في ترفهم
# [22:30.000 --> 22:34.000]  في نظرياتهم في فلسفاتهم
# [22:34.000 --> 22:38.000]  المطلوب أن يعيشوا آلام الناس
# [22:38.000 --> 22:42.000]  ليواجهوها وليعالجوها
# [22:42.000 --> 22:46.000]  في مسألة النفط والغاز والحدود البحرية
# [22:46.000 --> 22:50.000]  نحن على موقفنا المعروف
# [22:50.000 --> 22:54.000]  لا حاجة لأن أعيد كل ما قلناه
# [22:54.000 --> 22:58.000]  على مدى الأيام القليلة والأسابيع القليلة الماضية
# [22:58.000 --> 23:02.000]  نحن في الأيام المقبلة
# [23:02.000 --> 23:06.000]  ننتظر ما سيأتي به الأجوبة
# [23:06.000 --> 23:10.000]  ما ستأتي به الأجوبة على مطالب الدولة اللبنانية
# [23:10.000 --> 23:14.000]  وسنبني على الشيء مقتضاه
# [23:14.000 --> 23:18.000]  ولكن أقول لكم
# [23:18.000 --> 23:22.000]  في يوم العاشر في يوم عاشوراء
# [23:22.000 --> 23:26.000]  في يوم البصيرة والوعي في يوم الصبر
# [23:26.000 --> 23:30.000]  في يوم الثبات في يوم الفداء في يوم الدفاع عن الكرامات
# [23:30.000 --> 23:34.000]  أقول لكم ولكل اللبنانيين
# [23:34.000 --> 23:38.000]  وخصوصا لجمهور المقاومة وبالأخص لمجاهدين
# [23:38.000 --> 23:42.000]  المقاومة يجب أن نكون جاهزين لكل الاحتمالات
# [23:42.000 --> 23:46.000]  يجب أن نكون جاهزين ومستعدين
# [23:46.000 --> 23:50.000]  لكل الاحتمالات
# [23:50.000 --> 23:54.000]  نحن في هذه المعركة في هذا الاستحقاق
# [23:54.000 --> 23:58.000]  جادون إلى أبعد درجات الجدية
# [23:58.000 --> 24:02.000]  وكما قلت في الماضي أعيد اليوم
# [24:02.000 --> 24:06.000]  أقول للأمريكيين الذين يقدمون أنفسهم
# [24:06.000 --> 24:10.000]  وسطاء وهم ليسوا بوسطاء
# [24:10.000 --> 24:14.000]  وأقول للإسرائيليين لبنان وشعب لبنان
# [24:14.000 --> 24:18.000]  لا يمكن بعد اليوم أن يتسامح
# [24:18.000 --> 24:22.000]  بنهب ثرواته قلت في السابق وأعيد
# [24:22.000 --> 24:26.000]  نحن وصلنا إلى آخر الخط
# [24:26.000 --> 24:30.000]  وسنذهب إلى آخر الطريق
# [24:30.000 --> 24:34.000]  فلا يجربنا أحد ولا يمتحننا أحد
# [24:34.000 --> 24:38.000]  ولا يهددنا أحد ولا يراهن على أن
# [24:38.000 --> 24:42.000]  يخيفنا أحد
# [24:42.000 --> 24:46.000]  في الأيام القليلة الماضية
# [24:46.000 --> 24:50.000]  دقيقة بعد معي
# [24:50.000 --> 24:54.000]  في الأيام القليلة الماضية وحتى في
# [24:54.000 --> 24:58.000]  أجواء العدوان على غزة سمعنا العديد من
# [24:58.000 --> 25:02.000]  التصريحات والتهديدات والإشارات
# [25:02.000 --> 25:06.000]  بالتجاه لبنان ووضعهم كان يقول
# [25:06.000 --> 25:10.000]  أن فلان يذكروني أنا بالاسم
# [25:10.000 --> 25:14.000]  وناطق رسمي باسمكم يذكرون ويقولون
# [25:14.000 --> 25:18.000]  أن فلان قطعا اليوم يشاهد ما يجري
# [25:18.000 --> 25:22.000]  في هذه المعركة ويتلقى الرسائل المطلوبة
# [25:22.000 --> 25:26.000]  نعم نحن تلقينا الرسائل المطلوبة
# [25:26.000 --> 25:30.000]  ما شاهدناه في الأيام الماضية ثبات شعب غزة
# [25:30.000 --> 25:34.000]  وبطولة قادتها وتضامن فصائلها
# [25:34.000 --> 25:38.000]  وتبات مجاهديها وبصيرة
